# %%
import pandas as pd

# %%
llm_temperature = 0.2
retrieve_maxk = 4
llm = "hf.co/bartowski/Qwen2.5-3B-Instruct-GGUF:Q4_K_M"
embedder = "bge-m3:567m-fp16"

# %%
n = 10

q_arr = [None] * n
gt_arr = [None] * n
llm_answer_arr = [None] * n
rag_llm_full_recipe_answer_arr = [None] * n
rag_llm_recipe_and_ingredients_answer_arr = [None] * n
rag_llm_all_kinds_answer_arr = [None] * n

# %%
# fmt: off
gt_arr[0] = """1. яйца взбить с молоком, добавить тертую брынзу или сыр, мелко нарубленную зелень петрушки, молотые сухари, соль и перец.
2. стеклянную жаропрочную емкость смазать маслом, выложить подготовленную смесь и полить поверхность 3-4 ложками масла.
3. выпекать в духовке около получаса."""  # noqa: E501

q_arr[0] = "Напиши рецепт приготовления “зеленых” запеченных яиц."

llm_answer_arr[0] = """Для приготовления “зеленых” запеченных яиц вам понадобятся следующие ингредиенты и инструкции:
Ингредиенты:
4 яйца
1 столовая ложка растительного масла
Соль по вкусу
Зелень (укроп, петрушка или салат) для украшения
Шаги приготовления:
Взбейте яйца в глубокой миске.
Добавьте растительное масло и соль по вкусу, хорошенько перемешайте.
Нарежьте зелень на небольшие ломтики или кусочки.
Выложите яичную смесь в форму для запекания (можно использовать форму для запекания или глубокую тканевую салатницу).
Распределите зелень по поверхности яичной массы.
Запекайте в разогретой до 180 градусов духовке примерно 20-25 минут, или пока яйца не станут полностью приготовленными (можно проверить с помощью зубочистки).
Выньте запеченные яйца из духовки и дайте им остынуть на несколько минут.
Подавайте “зелеными” запеченными яйцами горячими или холодными."""  # noqa: E501

rag_llm_full_recipe_answer_arr[0] = """Шаг 1: Яйца взбить с молоком, добавить тертую брынзу или сыр, мелко нарубленную зелень петрушки, молотые сухари, соль и перец.
Шаг 2: Стеклянную жаропрочную емкость смазать маслом, выложить подготовленную смесь и полить поверхность 3-4 ложками масла.
Шаг 3: Выпекать в духовке около получаса."""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[0] = """название рецепта: зеленые запеченные яйца
ингредиенты:
желтки отваренных яиц
зелень укропа (мелко нарезанная)
масло растительное
сметана
молоко
соль
пошаговый рецепт: Шаг 1: из вареных яиц выньте желтки и протрите через сито. Добавьте немного соли. Шаг 2: в небольшую кастрюльку налейте молоко, добавьте желтки, перемешайте и нагрейте на медленном огне до загустения, постоянно помешивая, чтобы не пригорело. Шаг 3: выньте желтково-молочную смесь из кастрюли и перелейте в глубокую форму для запекания. Шаг 4: добавьте мелко нарезанную зелень укропа, хорошо перемешайте. Шаг 5: положите желтково-молочную смесь с зеленью в духовку и запекайте при температуре 180 градусов в течение 20 минут. Шаг 6: измельчите масло растительное, добавьте к желтковой смеси, перемешайте. Шаг 7: выньте запеченные яйца из духовки и полейте их полученной масляной смесью."""  # noqa: E501

rag_llm_all_kinds_answer_arr[0] = """Шаг 1: Яйца взбить с молоком, добавить тертую брынзу или сыр, мелко нарубленную зелень петрушки, молотые сухари, соль и перец.
Шаг 2: Стеклянную жаропрочную емкость смазать маслом, выложить подготовленную смесь и полить поверхность 3-4 ложками масла.
Шаг 3: Выпекать в духовке около получаса."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[1] = """1. яйца
2. молоко
3. зелень петрушки
4. брынза тертая или сыр тертый или панировочные сухари"
5. соль
6. перец
7. масло сливочное"""

q_arr[1] = "Напиши только ингредиенты для приготовления “зеленых” запеченных яиц списком без пояснений."  # noqa: E501

llm_answer_arr[1] = "Яйца, зелень (например, салат листовой), растительное масло, соль, перец."  # noqa: E501

rag_llm_full_recipe_answer_arr[1] = "яйца, молоко, зелень петрушки, брынза или сыр, панировочные сухари, соль, перец, масло сливочное."  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[1] = """яйца, молоко, зелень петрушки, брынза, сыр, панировочные сухари, соль, перец, масло сливочное."""  # noqa: E501

rag_llm_all_kinds_answer_arr[1] = """яйца, молоко, зелень петрушки, брынза, сыр, панировочные сухари, соль, перец, масло сливочное."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[2] = "колдовское блюдо"

q_arr[2] = """Какое блюдо можно приготовить из следующих ингредиентов:
* говядина
* вода
* вино красное
* лук репчатый
* чеснок
* тимьян сушеный измельченный
* перец чёрный
* морковь
* фасоль стручковая
* крахмал кукурузный
* бульонный кубик
Напиши только его название."""

llm_answer_arr[2] = "Говядина с соусом из красного вина и фасоли"

rag_llm_full_recipe_answer_arr[2] = "колдовское блюдо"

rag_llm_recipe_and_ingredients_answer_arr[2] = """колдовское блюдо"""

rag_llm_all_kinds_answer_arr[2] = """колдовское блюдо"""
# fmt: on

# %%
# fmt: off
gt_arr[3] = """название рецепта: "путер-гебекс" (масляная сдоба)

ингредиенты:
* мука пшеничная
* масло сливочное
* сметана
* яйца
* сахар
* соль
* корица

пошаговый рецепт:
шаг 1: муку просеять через сито горкой, сделать в середине ямку, положить в нее кусочки размягченного масла, сметану, яйца, соль, сахар и замесить тесто. поставить на холод на полчаса.
шаг 2: раскатать тесто в пласт толщиной 5 мм и формой для печенья или чашкой вырезать кружки диаметром 10 см. смазать кружки сахарным сиропом, посыпать толченой корицей, сложить вдвое и защипать края.
шаг 3: противень смазать маслом, выложить печенье наколоть вилкой и запечь в духовке."""  # noqa: E501

q_arr[3] = "Напиши полный рецепт ‘путер-гебекс (масляная сдоба)’ со списком ингредиентов."  # noqa: E501

llm_answer_arr[3] = """К сожалению, у меня нет информации о рецепте “Путер-гебекс (масляная сдоба)”. Возможно, это название является ошибкой или необычным вариантом названия блюда. Если вы можете предоставить дополнительные детали или точное название блюда, я постараюсь помочь вам найти рецепт."""  # noqa: E501

rag_llm_full_recipe_answer_arr[3] = """Вот полный рецепт “Путер-Гебекс (Масляная Сдоба)”:
Ингредиенты:
мука пшеничная - 200 г
масло сливочное - 100 г
сметана - 50 г
яйца - 3 шт.
сахар - 80 г
соль - 1 ч.л.
корица - 1/2 ч.л.
Пошаговый рецепт: Шаг 1: просеять муку через сито, сделать в середине ямку. В неё положить кусочки размягченного масла, сметану, яйца, соль и сахар. Замесить тесто. Поставить на холод на полчаса. Шаг 2: раскатать тесто в пласт толщиной 5 мм. Вырезать из него кружки диаметром 1 см. Смазать кружки сахарным сиропом, посыпать корицей, сложить вдвое и защипать края. Шаг 3: противень смазать маслом. Выложить печенье наколоть вилкой и запечь в духовке при температуре 180 градусов на 25 минут."""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[3] = """I apologize, but there is no known traditional recipe for “Путер-гебекс” or “Maksla Dobash” (which translates to “oil cake doughnut”). The provided context does not contain a recipe for this specific dish. It appears you might be referring to something else based on the name, as none of the given recipes match what is being asked for. Could you please provide more details or clarify which dish you are looking for?"""  # noqa: E501

rag_llm_all_kinds_answer_arr[3] = """К сожалению, предоставленный контекст содержит рецептуру для творожных пирожков с капустой и яйцами, но не содержит информации о “путер-гебекс (масляной сдобе)”. Для создания полного рецепта “путер-гебекса” нам нужно дополнительные инструкции и ингредиенты.
Вот примерный рецепт для “путер-гебекса”, основанный на масле, сливочном масле или оливковом масле:
Путер-Гебекс (Масляная Сдоба)
Ингредиенты:
200 грамм муки
150 грамм сахара
1 столовая ложка сливочного масла или оливкового масла
1 яйцо
Соль по вкусу
Инструкции:
В глубокой миске смешайте муку, сахар и соль.
Добавьте масло или масло и взбейте все ингредиенты до однородной массы.
Если тесто слишком густое, добавьте немного воды для получения консистенции, подобной тесту для пирога.
Выложите тесто на противень, смазанный маслом или кулинарным скотчем.
Поставьте противень в разогретую до 180 градусов духовку и выпекайте 20-30 минут.
Подготовка:
После выпечки, можно добавить различные ингредиенты для вкуса, например:
Ванильный сахар
Крупинки шоколада
Добавление фруктового сока или натурального варенья
Этот рецепт может быть адаптирован и дополнен по вашему усмотрению."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[4] = """название рецепта: «апельсиновый паук»

ингредиенты:
* лёд
* мороженое ванильное
* сок апельсиновый
* банан

пошаговый рецепт:
шаг 1: банан очистить, мелко нарезать, добавить к нему мороженое и апельсиновый сок. массу перемешать с помощью миксера, затем добавить лед и выложить в высокие стаканы. подавать сразу после приготовления."""  # noqa: E501

q_arr[4] = "Рецепт и ингредиенты «апельсиновый паук»"

llm_answer_arr[4] = """I apologize, but “апельсиновый паук” (which translates to “orange spider” in English) is not a common or well-known dessert recipe. It’s possible there might be some confusion with the name or it could be a regional dish that isn’t widely recognized outside its area of origin.
If you’re looking for an orange-based dessert, another popular option would be Orange Cheesecake or Orange Creamsicle ice cream. Could you please clarify if this is what you’re seeking?"""  # noqa: E501

rag_llm_full_recipe_answer_arr[4] = """Для рецепта “апельсиновый паук” вам понадобятся следующие ингредиенты:
Лед
Мороженое ванильное
Сок апельсиновый
Банан
Пошаговый рецепт:
Шаг 1: Очистите банан, нарезайте его мелко и добавьте к нему мороженое и сок апельсина. Перемешайте все вместе с помощью миксера. Затем добавьте лед в смесь и выложите в высокие стаканы. Подавайте сразу после приготовления."""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[4] = """Ингредиенты для рецепта “Апельсиновый Паук”:
Лед
Мороженое ванильное
Сок апельсиновый
Банан"""  # noqa: E501

rag_llm_all_kinds_answer_arr[4] = """Ингредиенты для рецепта “Апельсиновый Паук”:
Лед
Мороженое ванильное
Сок апельсиновый
Банан"""
# fmt: on

# %%
# fmt: off
gt_arr[5] = """*баклажаны крупный
* тахини кунжутное
* масло оливковое
* лимон (сок)
* соль
* перец молотый
* паприка молотая
* мята или зелень петрушки"""

q_arr[5] = "Выпиши список ингредиентов для рецепта «баба гануш»"

llm_answer_arr[5] = """I’m sorry, but “Баба Гануш” doesn’t appear to be a widely recognized dish or recipe name in English-speaking culinary contexts. Could you please provide more information about the origin of this dish? Perhaps there’s been a misinterpretation or transliteration error. If it is indeed from another language, could you specify which one?"""  # noqa: E501

rag_llm_full_recipe_answer_arr[5] = """баклажаны крупный
тахини кунжутное
масло оливковое
лимон (сок)
соль
перец молотый
паприка молотая
мята
или зелень петрушки"""

rag_llm_recipe_and_ingredients_answer_arr[5] = """Для приготовления бабы гануши (обычно это пирожное с кремом и начинкой) обычно используют следующие основные ингредиенты:
Масло растительное
Сахар
Яйца
Ванилин или ванильный сахар (для вкуса)
Хлопья кокосовые (или любые другие хлопья для начинки)
Для крема обычно используют:
Масло растительное
Сахар
Яйца
Щепотка соли
Но важно отметить, что конкретный рецепт может варьироваться в зависимости от региона и личных предпочтений. В некоторых вариантах могут использоваться дополнительные ингредиенты или заменители."""  # noqa: E501

rag_llm_all_kinds_answer_arr[5] = """The provided context does not contain a recipe for “Баба Гануш”. It appears to be a description of a vegetable salad with red fish, cucumbers, and egg pancakes. There is no list of ingredients or instructions given for the “Баба Гануш” dish. Please provide the correct recipe details if available."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[6] = """описание 1: прекрасный кисломолочный напиток, настоящая «аптека» на кислом молоке - айран. рецепт айрана очень распространен на кавказе. он пьется холодным, подсоленным и в жаркую погоду прекрасно утоляет жажду. айран вырабатывают из коровьего и овечьего молока.
описание 2: кисломолочный напиток айран легко можно приготовить в домашних условиях."""  # noqa: E501

q_arr[6] = "Напиши красивое, детальное описание рецепта “айран” без описания процесса готовки и ингредиентов"  # noqa: E501

llm_answer_arr[6] = """Изысканный айран - это легендарное кислое молоко, созданное из натурального козьего или коровьего молока. Его свежесть и непосредственность делают его идеальным напитком для тех, кто ценит простоту и естественность в приготовлении блюд. Этот напиток обладает уникальным вкусом - слегка кисловатым и немного терпким, что делает его незаменимым во время летних жаровых дней или после ужина. Айран не только охлаждает организм, но и способствует пищевому процессу, помогая переварить пищу. Его легкий вкус и аромат придают любому блюду изысканный оттенок, делая его еще более неповторимым и вкусным."""  # noqa: E501

rag_llm_full_recipe_answer_arr[6] = """Айран - это прекрасный кисломолочный напиток, настоящая аптека на кислом молоке. Его пьют холодным, подсоленным и в жаркую погоду он утоляет жажду великолепно. Айран вырабатывается из коровьего или овечьего молока и представляет собой плотный, желеобразный напиток, который готовится путем добавления кисломолочного продукта (например, простокваши или кефира) в кипящее молоко. После остывания и сквашивания он наслаждается своим вкусом, а его густота зависит от густоты исходного йогурта."""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[6] = """Очаровательный кисломолочный напиток айран представляет собой настоящую аптеку на кислом молоке. Этот уникальный напиток, который пьется холодным, подсоленным и в жаркую погоду, прекрасно утоляет жажду. Айран вырабатывается из коровьего или овечьего молока путем кислого переработки, что приводит к образованию сгустка и процессу сквашивания при температуре от 3 до 35 градусов Цельсия. После образования сгустка напиток подвергается выдержке в течение 1-12 часов при температуре 14-16 градусов Цельсия, что способствует его полному созреванию и улучшению вкусовых качеств. Айран готов к употреблению сразу после выдержки и подается холодным, чтобы сохранить все свои полезные свойства и ароматические качества."""  # noqa: E501

rag_llm_all_kinds_answer_arr[6] = """Название рецепта: Айран
Описание рецепта: Айран - это легендарное кулинарное блюдо, которое не только удивляет своим вкусом, но и завораживает своей историей. Это уникальная смесь молока и сыворотки, которая приобретает особую атмосферность благодаря добавлению соли и специй. Айран - это не просто напиток, он является символом тепла и дружбы в национальной кухне. Его легкий вкус и свежесть делают его идеальным выбором для тех, кто предпочитает здоровые и натуральные напитки. Этот простой рецепт приготовления айрана подчеркивает ценность естественных ингредиентов и способности кулинарных традиций сохранять свою свежесть и вкус на протяжении веков."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[7] = """описание 1: гуляш – традиционное венгерское блюдо, но рецепт гуляша давно завоевал кухни многих стран мира. гуляш можно приготовить из говядины, свинины, телятины, баранины.
описание 2: простое блюдо на обед. готовим гуляш. подойдет и свинина, и говядина. можно заправить гуляш чесноком.
описание 3: гуляш из говядины с подливкой популярен во многих странах, ведь в рецепте гуляша используются только простые и доступные ингредиенты. такое блюдо любят все хозяйки за быстроту и практичность. а гуляш из говядины с овощами, приготовленный по этому рецепту, получается очень ароматным, приправленный специями и чесночком, с насыщенным мясным вкусом."""  # noqa: E501

q_arr[7] = "Что такое гуляш?"

llm_answer_arr[7] = """Гуляш - это каша из мяса (обычно свинины или говядины), которая часто включает в себя различные овощи и специи, готовится на медленном огне. Это блюдо популярно в некоторых странах Балтии, особенно в Латвии и Литве."""  # noqa: E501

rag_llm_full_recipe_answer_arr[7] = """Гуляш - это традиционное венгерское блюдо, которое стало популярным на многих кухнях мира. Он может быть приготовлен из различных видов мяса, таких как говядина, свинина, телятина и баранина."""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[7] = """Гуляш - это популярное блюдо в кухне Венгрии. Оно обычно готовится из мяса (обычно свинины или говядины), нарезанного тонкими ломтиками, и специй. Готовят его в томатном соусе с добавлением овощей. Блюдо часто подают как первое блюдо или самостоятельным блюдом."""  # noqa: E501

rag_llm_all_kinds_answer_arr[7] = """Гуляш - это традиционная венгерская кухня бульон с мясом, который обычно готовится из свинины или говядины. Это блюдо может быть разнообразным, но обычно включает мясо, овощи и специи. Гуляш часто подают как первое блюдо или основное блюдо. В некоторых вариациях он может быть супом, а в других - это полноценное мясное блюдо."""  # noqa: E501
# fmt: on

# %%
# fmt: off
gt_arr[8] = """квас белый"""

q_arr[8] = "Какое блюдо (точное название) готовится по такому рецепту: ржаную, пшеничную, гречневую муку, ячменный и ржаной солод поочередно облить кипятком, замесить негустое тесто и выдержать в комнате 5 часов. развести кипятком, остудить, добавить дрожжи и выдержать в холодильнике 2 - 3 дня."  # noqa: E501

llm_answer_arr[8] = """Тесто для этого рецепта похоже на хлебную сдобу или ржаную закваску, но точное название блюда не указано в предоставленном рецепте."""  # noqa: E501

rag_llm_full_recipe_answer_arr[8] = """квас белый"""

rag_llm_recipe_and_ingredients_answer_arr[8] = """Цельнозерновой ржаной хлеб с льняной мукой и тмином"""  # noqa: E501

rag_llm_all_kinds_answer_arr[8] = """Квас белый"""
# fmt: on

# %%
# fmt: off
gt_arr[9] = """* коньяк
* кофе черный холодный
* яйца
* ликер кофейный
* молоко"""

q_arr[9] = "Какие ингредиенты нужны для мокко 32‑ног"

llm_answer_arr[9] = """Ваш запрос содержит опечатку - должно быть “мокшо” вместо “мокко”. Для приготовления классического мокшо (или шоколадного напитка) обычно используются следующие ингредиенты:
Молоко или молочный поросль
Сахар (по вкусу)
Шоколадный поросль (обычно 50-60% кacao)
Коричневый сахар (для украшения)
Помните, что количество сахара и шоколада можно регулировать в зависимости от вашего вкуса."""  # noqa: E501

rag_llm_full_recipe_answer_arr[9] = """Для приготовления “мокко 32ног” вам понадобятся следующие ингредиенты:
Коньяк
Кофе черный холодный
Яйца
Ликер кофейный
Молоко"""  # noqa: E501

rag_llm_recipe_and_ingredients_answer_arr[9] = """The provided context is about a recipe for “gander leg in honey sauce” and does not contain any information related to making mochi or “mocca 32-nog”. There seems to be a mix-up. Could you please clarify what specific ingredients are needed for your mochi dish?"""  # noqa: E501

rag_llm_all_kinds_answer_arr[9] = """В рецепте мокко 32-нога (мокко с 32 долей) обычно используются следующие ингредиенты:
Молоко - около 500 мл
Сахар - 1 столовая ложка
Карамельный шоколад или шоколадная паста - 2-3 чайные ложки
Кофе эспрессо - 1/4 стакана (или эквивалентное количество порошка кофе)
Сливочное масло - 10 граммов
Этот список может немного варьироваться в зависимости от конкретного рецепта и вкусовых предпочтений. Также можно добавить взбитые сливки для текстуры, если это требуется."""  # noqa: E501
# fmt: on

# %%
bench_dct = {
    "question": q_arr,
    "ground_truth_answer": gt_arr,
    "llm_answer": llm_answer_arr,
    "rag_llm_full_recipe_answer": rag_llm_full_recipe_answer_arr,
    "rag_llm_recipe_and_ingredients_answer": rag_llm_recipe_and_ingredients_answer_arr,
    "rag_llm_all_kinds_answer": rag_llm_all_kinds_answer_arr,
}

# %%
bench_df = pd.DataFrame(bench_dct)
bench_df
# Out:
#                                             question  \
# 0  Напиши рецепт приготовления “зеленых” запеченн...
# 1  Напиши только ингредиенты для приготовления “з...
# 2  Какое блюдо можно приготовить из следующих инг...
# 3  Напиши полный рецепт ‘путер-гебекс (масляная с...
# 4           Рецепт и ингредиенты «апельсиновый паук»
# 5  Выпиши список ингредиентов для рецепта «баба г...
# 6  Напиши красивое, детальное описание рецепта “а...
# 7                                   Что такое гуляш?
# 8  Какое блюдо (точное название) готовится по так...
# 9           Какие ингредиенты нужны для мокко 32‑ног
#
#                                  ground_truth_answer  \
# 0  1. яйца взбить с молоком, добавить тертую брын...
# 1  1. яйца\n2. молоко\n3. зелень петрушки\n4. бры...
# 2                                   колдовское блюдо
# 3  название рецепта: "путер-гебекс" (масляная сдо...
# 4  название рецепта: «апельсиновый паук»\n\nингре...
# 5  *баклажаны крупный\n* тахини кунжутное\n* масл...
# ...

# %%
bench_df.to_parquet("../data/ragllm_vs_llm.parquet")
