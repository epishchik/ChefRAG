# %%
import pandas as pd

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)

# %%
full_recipe_chunks = pd.read_parquet("../data/full_recipe_chunks.parquet")
full_recipe_chunks
# Out:
#           id  \
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 92139  92139
# 92140  92140
# 92141  92141
# 92142  92142
# 92143  92143
#
# ...

# %%
all_kinds_chunks = pd.read_parquet("../data/all_kinds_chunks.parquet")
all_kinds_chunks
# Out:
#         chunk_id  recipe_id   chunk_type  \
# 0              0          0        title
# 1              1          0  description
# 2              2          0  ingredients
# 3              3          0  recipe_part
# 4              4          0  recipe_part
# ...          ...        ...          ...
# 806322    806322      92142  recipe_part
# 806323    806323      92143        title
# 806324    806324      92143  ingredients
# 806325    806325      92143  recipe_part
# 806326    806326      92143  recipe_part
#
#                                                                                                                                                                                                                                                                                                               chunk_text  \
# ...

# %%
recipe_and_ingredients_chunks = pd.read_parquet(
    "../data/recipe_and_ingredients_chunks.parquet"
)
recipe_and_ingredients_chunks
# Out:
#         chunk_id  recipe_id   chunk_type  \
# 0              0          0       recipe
# 1              1          0  ingredients
# 2              2          1       recipe
# 3              3          1  ingredients
# 4              4          2       recipe
# ...          ...        ...          ...
# 184188    184188      92141  ingredients
# 184189    184189      92142       recipe
# 184190    184190      92142  ingredients
# 184191    184191      92143       recipe
# 184192    184192      92143  ingredients
#
# ...
